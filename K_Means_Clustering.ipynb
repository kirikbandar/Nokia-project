# %%
# !pip install six python-firebase
from firebase import firebase
import tensorflow as tf
import json
import logging
import flask
from flask import Flask
from firebase import firebase
import json
import tensorflow as tf
import sklearn
from sklearn.cluster import KMeans
import matplotlib
import matplotlib.pyplot as plt
import mpl_toolkits
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
from sklearn import datasets
# Out:
# ...
#   Created wheel for python-firebase: filename=python_firebase-1.2-cp36-none-any.whl size=11535 sha256=3d081d5b791db310c9bf92bdc335efb6cd9725346c3d16db705049c4f380a361
#   Stored in directory: /root/.cache/pip/wheels/ba/40/ca/e41a25d7abb787092e837cb0f91f33b04b1a8fd9d17c2d33a6
# Successfully built python-firebase
# ...

# %%
#Train (actual) code
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
# %matplotlib inline
from sklearn import datasets

import json

with open('/content/data10k.json') as f:
  d = json.load(f)
X=[[0 for i in range(3)] for j in d['users']['users']]
c=0
for i in d['users']['users']:
  X[c][0]=(d['users']['users'][i]['latitude'])
  X[c][1]=(d['users']['users'][i]['longitude'])
  X[c][2]=(d['users']['users'][i]['rssi'])
  c=c+1
print(c)
print("hi")
X=np.asarray(X)

  
#Iris Dataset
#iris = datasets.load_iris()
#X = iris.data
#KMeans
km = KMeans(n_clusters=3)
km=km.fit(X)
km.predict(X)
labels = km.labels_
#Plotting
fig = plt.figure(1, figsize=(7,7))
ax = Axes3D(fig, rect=[0, 0, 0.95, 1], elev=48, azim=134)
ax.scatter(X[:, 0], X[:, 1], X[:, 2],
          c=labels.astype(np.float), edgecolor="k", s=50)
ax.set_xlabel("Latitude")
ax.set_ylabel("Longitude")
ax.set_zlabel("RSSI")
plt.title("K Means", fontsize=14)
# Out:
# 10102
# hi
# Text(0.5, 0.92, 'K Means')

# %%
#to save and load the model km
import pickle
filename="/content/kmeans.h5"
pickle.dump(km, open(filename, 'wb')) #Saving the model
model = pickle.load(open(filename, 'rb')) #To load saved model from local directory
