# %%
# !pip install six python-firebase
from firebase import firebase
import tensorflow as tf
import json
import logging
import flask
from flask import Flask
from firebase import firebase
import json
import tensorflow as tf
import sklearn
from sklearn.cluster import KMeans
import matplotlib
import matplotlib.pyplot as plt
import mpl_toolkits
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
from sklearn import datasets
# Out:
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (1.12.0)
# Collecting python-firebase
#   Downloading https://files.pythonhosted.org/packages/32/e6/88b799753e64aeb0f24040b98c94012994cf9517c889dee4f8a49ac89400/python-firebase-1.2.tar.gz
# Requirement already satisfied: requests>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from python-firebase) (2.23.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=1.1.0->python-firebase) (2020.4.5.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=1.1.0->python-firebase) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=1.1.0->python-firebase) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=1.1.0->python-firebase) (2.9)
# Building wheels for collected packages: python-firebase
#   Building wheel for python-firebase (setup.py) ... done
#   Created wheel for python-firebase: filename=python_firebase-1.2-cp36-none-any.whl size=11535 sha256=3d081d5b791db310c9bf92bdc335efb6cd9725346c3d16db705049c4f380a361
#   Stored in directory: /root/.cache/pip/wheels/ba/40/ca/e41a25d7abb787092e837cb0f91f33b04b1a8fd9d17c2d33a6
# Successfully built python-firebase
# Installing collected packages: python-firebase
# Successfully installed python-firebase-1.2

# %%
import json
f=firebase.FirebaseApplication('https://androidlocation-cdecd.firebaseio.com/')
result=f.get('new_users',None)
print(result)
with open('check.json', 'w') as json_file:
    json.dump(result, json_file)
# Out:
# {'-M5ugP0x958GWPl2oZHK': {'ip': '192.168.31.243', 'latitude': 13.0433597, 'longitude': 77.5785849, 'name': 'Vodafone IN', 'rssi': -2147483647}, '-M5ugRTMSgEqTYcJ_S4O': {'ip': '192.168.31.243', 'latitude': 13.0433597, 'longitude': 77.5785849, 'name': 'Vodafone IN', 'rssi': -2147483647}, '-M5ukGFEwseOHQeiqXIq': {'ip': '192.168.0.103', 'latitude': 12.8794957, 'longitude': 77.5290865, 'name': 'airtel', 'rssi': -5}, '-M5ukJfcO1YYEL_7zqMm': {'ip': '192.168.0.103', 'latitude': 12.8794933, 'longitude': 77.529054, 'name': 'airtel', 'rssi': -5}, '-M5upwkcbQG84ggY88XP': {'ip': '192.168.0.101', 'latitude': 12.9220519, 'longitude': 77.5040724, 'name': 'airtel', 'rssi': -9}, '-M5upzDHljRoGc_43vTO': {'ip': '192.168.0.101', 'latitude': 12.9220519, 'longitude': 77.5040724, 'name': 'airtel', 'rssi': -10}, '-M5uq5hyDQFX33kg7dUU': {'ip': '192.168.1.22', 'latitude': 12.8370245, 'longitude': 77.6963385, 'name': 'Vodafone IN', 'rssi': -2147483647}, '-M5uq7MMvlHx3k24u_O6': {'ip': '192.168.1.22', 'latitude': 12.8370245, 'longitude': 77.6963385, 'name': 'Vodafone IN', 'rssi': -2147483647}, '-M5uq7MlNANlB4odl1ps': {'ip': '192.168.1.22', 'latitude': 12.8370245, 'longitude': 77.6963385, 'name': 'Vodafone IN', 'rssi': -2147483647}, '-M5uq7qcwPRcxbY0ztnR': {'ip': '192.168.1.22', 'latitude': 12.8370024, 'longitude': 77.6963342, 'name': 'Vodafone IN', 'rssi': -2147483647}, '-M5uqAIS2EHHVrLdm4pb': {'ip': '192.168.1.22', 'latitude': 12.8369979, 'longitude': 77.6963854, 'name': 'Vodafone IN', 'rssi': -2147483647}, '-M5uqBYMsWLJ-foJwy7u': {'ip': '192.168.1.22', 'latitude': 12.8374811, 'longitude': 77.6963999, 'name': 'Vodafone IN', 'rssi': -2147483647}, '-M5uqCsSMerX-vUro65q': {'ip': '192.168.1.22', 'latitude': 12.8373679, 'longitude': 77.69654, 'name': 'Vodafone IN', 'rssi': -2147483647}, '-M5uqEDpspgAmX4m50kw': {'ip': '192.168.1.22', 'latitude': 12.83712, 'longitude': 77.6966173, 'name': 'Vodafone IN', 'rssi': -2147483647}, '-M5uqFXSHIoLq5x2AHXJ': {'ip': '192.168.1.22', 'latitude': 12.8370716, 'longitude': 77.6966059, 'name': 'Vodafone IN', 'rssi': -2147483647}, '-M5uqGvHfAErO7gGKIqD': {'ip': '192.168.1.22', 'latitude': 12.8370665, 'longitude': 77.6965639, 'name': 'Vodafone IN', 'rssi': -2147483647}, '-M5uqIEJGiiIzLobtrBK': {'ip': '192.168.1.22', 'latitude': 12.8370566, 'longitude': 77.6965754, 'name': 'Vodafone IN', 'rssi': -2147483647}, '-M5uqJbY-C1B4quT9INO': {'ip': '192.168.1.22', 'latitude': 12.837033, 'longitude': 77.6965921, 'name': 'Vodafone IN', 'rssi': -2147483647}, '-M5uqL34lpDGupvQdS_o': {'ip': '192.168.1.22', 'latitude': 12.8369852, 'longitude': 77.6965519, 'name': 'Vodafone IN', 'rssi': -2147483647}, '-M5uqMIHyklQ0qskiKXP': {'ip': '192.168.1.22', 'latitude': 12.8369654, 'longitude': 77.6964522, 'name': 'Vodafone IN', 'rssi': -2147483647}, '-M5uqNWQVcsuteuiy35e': {'ip': '192.168.1.22', 'latitude': 12.8370056, 'longitude': 77.6963179, 'name': 'Vodafone IN', 'rssi': -2147483647}, '-M5uqOj_KZv1BFMhOcWC': {'ip': '192.168.1.22', 'latitude': 12.837012, 'longitude': 77.6963826, 'name': 'Vodafone IN', 'rssi': -2147483647}, '-M5uqQ4NUxgkSEcQ13NZ': {'ip': '192.168.1.22', 'latitude': 12.8370156, 'longitude': 77.696469, 'name': 'Vodafone IN', 'rssi': -2147483647}, '-M5uqRIZmR9oBv5bwq3v': {'ip': '192.168.1.22', 'latitude': 12.8370583, 'longitude': 77.6964986, 'name': 'Vodafone IN', 'rssi': -2147483647}, '-M5uqSd_5ykhrAZn0MsJ': {'ip': '192.168.1.22', 'latitude': 12.8370769, 'longitude': 77.6964489, 'name': 'Vodafone IN', 'rssi': -2147483647}, '-M5uqTzM6jv4nlmZI6bo': {'ip': '192.168.1.22', 'latitude': 12.8371086, 'longitude': 77.6964463, 'name': 'Vodafone IN', 'rssi': -2147483647}, '-M5uqVCZaVs13IzdrGbd': {'ip': '192.168.1.22', 'latitude': 12.837084, 'longitude': 77.6964243, 'name': 'Vodafone IN', 'rssi': -2147483647}, '-M5uqWTc_mHb95Jr2fu5': {'ip': '192.168.1.22', 'latitude': 12.8370824, 'longitude': 77.6964373, 'name': 'Vodafone IN', 'rssi': -2147483647}, '-M5uqXjoMgUlicMqBxTL': {'ip': '192.168.1.22', 'latitude': 12.8370904, 'longitude': 77.6964287, 'name': 'Vo ...
